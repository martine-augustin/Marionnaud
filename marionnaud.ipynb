# %% [markdown]
# <a href="https://colab.research.google.com/github/martine-augustin/Marionnaud/blob/main/marionnaud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Marionnaud projet

# %% [markdown]
# ## Variable et installation

# %%
# Install
# !pip install beautifulsoup4
# !pip install lxml
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (6.0.2)

# %%
# Import
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import time
import random
import csv
import pandas as pd

# %%
#Constante
id_avis = 0
page_avis = 0
page_avis_end = False
liste_des_avis = list()

# %% [markdown]
# ## Fonction

# %%
def unAvis(section):
    global id_avis

    img_star = section.find('img', class_='CDS_StarRating_starRating__614d2e')
    if not img_star:
        return None

    nb_etoile_text = img_star.get('alt')
    nb_etoile = nb_etoile_text[5]

    date_commentaire_tag = section.find('span')
    if not date_commentaire_tag or not nb_etoile.isdigit():
        return None

    date_commentaire = date_commentaire_tag.get_text(strip=True)
    if not date_commentaire[0].isdigit():
        return None

    id_avis += 1
    titre_tag = section.find('h2')
    titre = titre_tag.get_text(strip=True) if titre_tag else None

    commentaire_tag = section.find('p')
    commentaire_text = commentaire_tag.get_text(strip=True) if commentaire_tag else None

    return [id_avis, page_avis, nb_etoile, date_commentaire, titre, commentaire_text]

# %%
def PageAvis(url):
    liste_des_avis_page = []

    # Récupérer le contenu de la page avec requests
    response = requests.get(url)

    if response.status_code != 200:
        return "Error"

    # Parser le HTML
    soup = BeautifulSoup(response.text, 'html.parser')
    sections = soup.find_all('section')  # toutes les sections

    for section in sections:
        avis = unAvis(section)
        if avis:  # si unAvis renvoie bien une liste
            liste_des_avis_page.append(avis)

    return liste_des_avis_page

# %%
def CreateCSV(tab_avis):
  with open("avis.csv", mode="w", newline="", encoding="utf-8") as fichier_csv:
    writer = csv.writer(fichier_csv)

    # Écrire une ligne d'en-tête
    writer.writerow(["Avis ID", "Page ID", "Nombre etoile", "Date", "Titre", "Commentaire"])

    # Écrire les données
    for ligne in tab_avis:
        writer.writerow(ligne)

# %%
def OpenCSV(filename):
    """
    Ouvre un fichier CSV et retourne un DataFrame pandas
    """
    try:
        df = pd.read_csv(filename, encoding="utf-8")
        return df
    except FileNotFoundError:
        print(f"Erreur : le fichier {filename} n'existe pas.")
        return None
    except pd.errors.EmptyDataError:
        print(f"Erreur : le fichier {filename} est vide.")
        return None

# %% [markdown]
# ## Scrapping

# %%
#On recupere les avis de toutes les pages Marionnaud
while page_avis_end == False:

  page_avis += 1
  url = 'https://fr.trustpilot.com/review/www.marionnaud.com?page=' + str(page_avis)

  result = PageAvis(url)
  if(result != "Error"):
    #On fusionne notre tableau temporaire avec le tableau principal

    if liste_des_avis:
      liste_des_avis = liste_des_avis + result
    else:
      liste_des_avis = result

    # Génère un nombre entier aléatoire entre 45 et 60
    delai = random.randint(45, 60)
    print("Début du timeur de la page : " + str(page_avis) + " en cours ...")
    time.sleep(60)  # attend 5 secondes

  else:
    page_avis_end = True

  # A supprimer une fois les cherck fini
  print("--------------------------")
  print("url :" + url)
  print(result)
  print("nombre élément liste_des_avis : " + str(len(liste_des_avis)))

print(liste_des_avis)
CreateCSV(liste_des_avis)
# Out:
# Début du timeur de la page : 1 en cours ...
# --------------------------
# url :https://fr.trustpilot.com/review/www.marionnaud.com?page=1
# [[1, 1, '4', '18 février 2026', 'Très bonne expérience globale', 'Très bonne expérience globale.Très bon rapport qualité prix.Très bon accueil.Avantage du programme fidélité intéressant.'], [2, 1, '5', '13 février 2026', 'Top niveau.', 'Simple, rapide, efficace en étant toujours professionnel ET sympathique.'], [3, 1, '5', '11 février 2026', 'Équipe très accueillante sympa et les…', 'Équipe très accueillante sympa et les conseillères toujours de très bon conseils .'], [4, 1, '1', '13 février 2026', 'Commande passée le colis est arrivé…', 'Commande passée le colis est arrivé avec des produits qui ne sont pas les miens ainsi que bon de livraison ne correspondant pas à mes coordonnées. Appel ce jour au service client c est à moi de renvoyer le mauvais colis sans dédommagement (frais d\'essence +impression du bon de retour) pour être remboursée seulement après cette envoi de ma commande. Hors je ne souhaite pas être remboursée mais avoir ma commande on m\'annonce que c\'est impossible et qu\'il faudra repasser commande (sachant que j\'ai bénéficié d\'offres promotionnelles qui sont expirées ) je demande un dédommagement on m\'annonce que ce n\'est pas possible, je demande à parler à un supérieur même réponse "ce n\'est pas possible". La personne au téléphone du service client ne parlait même plus.Je suis vraiment mécontente de la qualité du service marionnaud. Je ne serais plus cliente sauf si une solution m\'est proposée.'], [5, 1, '1', '6 décembre 2025', 'Aucun remboursement en cas colis perdu', 'Colis perdu par la poste et confirmé perdu par la poste. Le service client ne répond pas aux mailsPas de remboursement depuis 2 mois'], [6, 1, '2', '8 février 2026', 'Prix élevés, promotions non fiables et service client inexistant', 'J’ai rencontré plusieurs problèmes avec Marionnaud ces derniers temps, à la fois en boutique et via l’application, qui m’amènent à reconsidérer mes achats dans cette enseigne. En décembre, j’ai réservé un soin Kobido (environ 60 €) en boutique/institut. Instant zen raté : le personnel allait et venait bruyamment, verre à la main. De plus, les cabines étaient situées dans un sous-sol peu entretenu. Plus récemment, lors d’une commande en ligne effectuée pendant une opération promotionnelle -30 %, le cadeau annoncé pour un montant minimum d’achat n’a pas été honoré lors du retrait en boutique. J’ai constaté également des dysfonctionnements récurrents de l’application mobile : lorsque plusieurs remises se cumulent (promotions +avantages club privé +cagnotte), l’application devient inutilisable et empêche de finaliser la commande. Les prix de départ pratiqués par l’enseigne sont très élevés, ce qui rend problématique le non-respect ou le dysfonctionnement des offres promotionnelles censées atténuer le coût. Pour bénéficier de prix corrects, il est nécessaire de souscrire au Club Privé (12€), présenté comme programme fidélité “premium”. J’ai également constaté que le service client répond souvent par des messages automatisés de type “fin de non-recevoir”, ce qui évoque un manque de considération pour le client. Ce service client n’existe simplement pas. Ces expériences successives me donnent le sentiment d’un manque de fiabilité des offres et d’une faible considération du client lorsque les
026', 'Merci a Loubna de son accueil', 'Merci a Loubna de son accueil, bonne conseillère, souriante et agréable, magasin petit mais reste chaleureux.Je reviendrai..'], [30, 2, '5', '19 janvier 2026', 'Elles sont gentille et de bon conseils .', 'Elles sont gentille et de bon conseil.'], [31, 2, '5', '19 janvier 2026', 'Merci beaucoup à la vendeuse loubna 👍de…', "Merci beaucoup à la vendeuse loubna 👍de chez marionnaud la valette 83 super conseillère ravi de mes achats même si j'ai fait chauffer la carte bleu je ne regrette pas merci milles fois à vous ❤️👍👍👍👍👍👍👍"], [32, 2, '1', '18 octobre 2025', 'Je vous invite a fuire cette enseigne…', "Je vous invite a fuire cette enseigne qui ne respecte pas ces clients. Une ignorance des plus totale ! J'ai déjà fait un avis négatif mais je suis obligée de revenir pour en faire un second. J'ai contacté le numero indiqué dans le mail de réclamation. Je leur ai dit qu'une personne dans la même situation que moi (demande de remboursement sur produit reçu non conforme au conditionnement indiqué lors de l'achat) a reçu un remboursement et la on me répond que je vais être remboursé. Des semaines plus tard et  après plusieurs appels m'informant que mon dossier a été mis a l'état de très urgent en date du 18 décembre, soit il y près de 1 mois.Et bien de nouveau, aucun retour, pourtant les personnes au téléphone m'assure que le remboursement va être fait sous peu... Mais toujours rien!C'est vraiment INADMISSIBLEFaire la sourde oreille en espérant que le client s'épuise et arrête les relances... C'est une honte, vraiment"], [33, 2, '5', '14 janvier 2026', 'De bons professionnels', 'Bon accueilBons renseignemen ...
# nombre élément liste_des_avis : 40
# Début du timeur de la page : 3 en cours ...
# --------------------------
# url :https://fr.trustpilot.com/review/www.marionnaud.com?page=3
# [[41, 3, '5', '10 janvier 2026', 'Comme à l habitude de bons conseils', 'Comme à l habitude de bons conseils'], [42, 3, '4', '9 janvier 2026', 'Le choix des produits', "Le choix des produits, l'ambiance du magasin."], [43, 3, '5', '7 janvier 2026', 'Marionnaud', 'Marionnaud, c’est mon magasin préféré plus d’achat plus davantage, je recommande et je préfère mes deux magasins, celui de Vaulx-en-Velin, cette chemin et celle de Saxe'], [44, 3, '5', '6 janvier 2026', 'Jai été accueilli par Samira avec un…', "Jai été accueilli par Samira avec un grand sourire , qui ma bien conseiller j'ai appréciée cet accueil . Par ailleurs je trouve l'enseigne  Mariaunaud irrespectueuse du client j'achète pour 180€ et seulement 2petits échantillons comme récompenses envers la cliente,   tres déçu, heureusement que la vendeuse était gracieuse et compétente.Nathalie"], [45, 3, '1', '9 janvier 2026', "J'ai acheté un coffret les quantités de…", "J'ai acheté un coffret les quantités de produit ne sont pas au RDVUn gel douche qui n'a pas la présentation habituelle des gel douche Quantité médiocre et prix exorbitant....c'est de l'escroquerie.Jamais plus marionnaud.😡"], [46, 3, '1', '21 novembre 2025', 'Ils ne veulent pas me rembourser', "J’ai passé une commande le 21/11/2025 (commande n°1400133519) d'un montant de 968,34 euros. Par erreur de la part de Marionnaud, j’ai reçu la commande d’une autre personne. Suite à un échange avec le service client, j’ai renvoyé le colis afin d’obtenir un remboursement. Le colis a bien été reçu par Marionnaud.Cependant, ils ne m’ont remboursé qu’un tiers du montant total de ma commande. Cela fait maintenant 5 semaines que je relance une vingtaine de fois pour récupérer le reste de mon argent soit 645,56 euros, et la réponse est toujours la même : « le dossier est en cours de traitement ».Un service client totalement incompétent. J’ai perdu énormément de temps et mon argent reste bloqué chez eux, alors que cette commande était destinée à des cadeaux de Noël. Svp Remboursez moi mon argent!!!!!"], [47, 3, '5', '6 janvier 2026', 'La découverte de la gamme serge luthens…', "La découverte de la gamme serge luthens après tant d'année"], [48, 3, '5', '3 janvier 2026', 'L’accueil au top quelle énergie merci', 'L’accueil au top quelle énergie merci'], [49, 3, '5', '23 décembre 2025', 'Toujours au top', 'Toujours au top'], [50, 3, '5', '30 décembre 2025', 'Accueil chaleureux et conseils personnalisés', 'Accueil chaleureux des conseillères du Marionnaud de Vincennes. Conseils avisés et adaptés à mes besoins. Je suis repartie avec le produit que je cherchais. Je recommande !'], [51, 3, '5', '31 décembre 2025', 'Une équipe souriante', "Une équipe souriante, accueillante , toujours à l'écoute"], [52, 3, '5', '29 décembre 2025', 'Satisfaction', "BonjourLa qualité première de Marionaud que je souligne à travers ces quelques lignes c'est l'accueil réservé aux clients, la mise en avant des produits et la propreté du magasin.Cordialement"], [53, 3, '5', '28 décembre 2025', 'Accueil excellent', 'Accueil excellent, professionnel, agréable au contact, conseils à notre attente, juste et précis, fidélité de notre part. Merci.'], [54, 3, '5', '28 décembre 2025', 'Super', 'Accueil sympathique et de bons conseilsJe recommande'], [55, 3, '1', '12 novembre 2025', 'Site de voleur', 'Site de voleurDepuis le 24 novembre ils me disent avoir remboursé le retour sur paypal hors paypal n’a absolument rien reçu. J’ai même ouvert un litige qui a été clôturé en faveur de Marionnaud alors qu’ils ont reçu mon retourTu fais un retour tu es censé récupérer ton argent et ont arnaque.Signalement fait auprès de la DGCCRF pour marionnaud et paypal qui collabore pour arnaquer les gens.1400027969'], [56, 3, '5', '27 décembre 2025', 'À chaque passage chez Marionnaud', 'À chaque passage chez Marionnaud, je ressors ravi, et cette dernière visite n’a fait que confirmer pourquoi j’aime tant cette parfumerie. Un immense bravo à Milouda, une vendeuse tout simplement remarquabl ...
# nombre élément liste_des_avis : 60
# Début du timeur de la page : 4 en cours ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4054745949.py in <cell line: 0>()
#      17     delai = random.randint(45, 60)
#      18     print("Début du timeur de la page : " + str(page_avis) + " en cours ...")
# ---> 19     time.sleep(60)  # attend 5 secondes
#      20
#      21   else:
#
# KeyboardInterrupt:

# %%
# Ouvrir le CSV créé précédemment
df_avis = OpenCSV("avis.csv")

# Vérifier que ça a fonctionné
if df_avis is not None:
    print(df_avis.head())  # affiche les 5 premières lignes
